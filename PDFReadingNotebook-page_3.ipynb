# %%
import cv2
import sys
import pytesseract
import Database
from IPython.display import Image

# %%
arrFrames = []

# %%
def getStringInRect(x,y,width,height):
  imPath = "images/page_3.png"  
  # Uncomment the line below to provide path to tesseract manually
  # pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
 
  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' for using LSTM OCR Engine
  config = ('-l eng --oem 1 --psm 3')
 
  # Read image from disk
  im = cv2.imread(imPath, cv2.IMREAD_COLOR)

  crop_img = im[y:y+height, x:x+width]
  text = pytesseract.image_to_string(crop_img, config=config)
  return text

# %%
Image("images/page_3.png")

# %%
def plotSquare(x,y,width,height):
  imPath = "images/page_3.png"  
  # Uncomment the line below to provide path to tesseract manually
  # pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
 
  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' for using LSTM OCR Engine
  config = ('-l eng --oem 1 --psm 3')
 
  # Read image from disk
  im = cv2.imread(imPath, cv2.IMREAD_COLOR)
  cv2.rectangle(im, (x, y), (x+width, y+height), (255,0,0), 2)
  cv2.imwrite("me.png",im)

# %%
def findStringInRange(strFind,x,y,maxWidth,maxHeight):
  width = 10
  height = 10

  while height < maxHeight:
    width = 10
    while width < maxWidth:
      strTmpText = getStringInRect(x,y,width,height)
      if strTmpText == strFind:
        print(x)
        print(y)
        return x,y,width,height
      else:
        width = width + 5
    height = height + 5

# %%
if __name__ == '__main__':
 
  if len(sys.argv) < 1:
    print('Usage: python ocr_simple.py image.jpg')
    sys.exit(1)

strTmpText = "disqualified persons "
#plotSquare(10,430,790,25)
#text =  getStringInRect(10,430,790,25)
#findStringInRange("2 Savings and temporary cash investments",60,50,1000,1000)
# print(text)
# print("---------------------------------------------------------------------------------------")

# %%
def readAT(x,y,width,height,type="dynamic",caption=""):
    text =  getStringInRect(x,y,width,height)
    plotSquare(x,y,width,height)
    
    dictTmpFrame = {}
    dictTmpFrame["frame"] = {"x":x,"y":y,"width":width,"height":height}
    dictTmpFrame["type"] = type
    dictTmpFrame["caption"] = caption
    if type == "static":
        dictTmpFrame["value"] = text
    elif type == "dynamic":
        dictTmpFrame["value"] = text
    
    arrFrames.append(dictTmpFrame.copy())
    print(text)
    print("---------------------------------------------------------------------------------------")

# %%
y = 0
height = 40

readAT(10,y,1680,height,type="static")
# readAT(780,y,245,height)
# readAT(1025,y,240,height)
# readAT(1260,y,200,height)
# readAT(1460,y,230,height)
#Image("me.png")
# Out:
# Form 990-PF (2012) Padae 3
# ---------------------------------------------------------------------------------------

# %%
y = 40
height = 40

readAT(10,y,1700,height, type="static")
# readAT(780,y,245,height)
# readAT(1025,y,240,height)
# readAT(1260,y,200,height)
# readAT(1460,y,230,height)
#Image("me.png")
# Out:
# | Part IV] Capital Gains and Losses for Tax on Investment Income
# ---------------------------------------------------------------------------------------

# %%
y = 80
height = 85

readAT(10,y,1000,height, type="static")
readAT(1010,y,220,height, type="static")
readAT(1230,y,220,height, type="static")
readAT(1450,y,220,height, type="static")
#Image("me.png")
# Out:
# (a) List and describe the kind(s) of property sold (eg , real estate,
# 2-story brick warehouse, or common stock, 200 shs MLC Co)
# ---------------------------------------------------------------------------------------
# (b) How acquired
# P—Purchase
# D—Donation
# ---------------------------------------------------------------------------------------
# (c) Date acquired
# (mo , day, yr)
# ---------------------------------------------------------------------------------------
# (d) Date sold
# (mo , day, yr )
# ---------------------------------------------------------------------------------------

# %%
y = 170
height = 40

readAT(20,y,1000,height)
# readAT(1025,y + 5,180,height - 15)
# readAT(1230,y,220,height)
# readAT(1450,y,220,height)
Image("me.png")
# Out:
# la PUBLICLY TRADED SECURITIES
# ---------------------------------------------------------------------------------------

# %%
y = 210
height = 40

readAT(10,y,1000,height)
readAT(1015,y,215,height)
readAT(1230,y,220,height)
readAT(1450,y,220,height)
# readAT(1460,y,230,height)
#Image("me.png")
# Out:
# b ALTERNATIVE INVESTMENTS
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 250
height = 40

readAT(10,y,1000,height)
readAT(1015,y,215,height)
readAT(1230,y,220,height)
readAT(1450,y,220,height)
#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 290
height = 40

readAT(10,y,1000,height)
readAT(1015,y,215,height)
readAT(1230,y,220,height)
readAT(1450,y,220,height)
# readAT(1460,y,230,height)
# Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 330
height = 40

readAT(10,y,1000,height)
readAT(1015,y,215,height)
readAT(1230,y,220,height)
readAT(1450,y,220,height)
# readAT(1460,y,230,height)
# Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 370
height = 65

readAT(10,y,450,height, type="static")
readAT(460,y,390,height, type="static")
readAT(850,y,390,height, type="static")
readAT(1240,y,420,height, type="static")

# Image("me.png")
# Out:
# (e) Gross sales price
# ---------------------------------------------------------------------------------------
# (f) Depreciation allowed
# (or allowable)
# ---------------------------------------------------------------------------------------
# (g) Cost or other basis
# plus expense of sale
# ---------------------------------------------------------------------------------------
# (h) Gain or (loss)
# (e) plus (f) minus (g)
# ---------------------------------------------------------------------------------------

# %%
y = 430
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,390,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# 1,863,739,713
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 1,798,397 ,027
# ---------------------------------------------------------------------------------------
# 65,342,686
# ---------------------------------------------------------------------------------------

# %%
y = 470
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,390,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 33,654,603
# ---------------------------------------------------------------------------------------

# %%
y = 510
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,390,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 550
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,390,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 590
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,390,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 630
height = 40

readAT(10,y,1220,height)
# readAT(460,y,390,height)
# readAT(850,y,390,height)
# readAT(1240,y,420,height)

#Image("me.png")
# Out:
# Complete only for assets showing gain In column (h) and owned by the foundation on 12/31/69
# ---------------------------------------------------------------------------------------

# %%
y = 670
height = 60

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,385,height)
readAT(0,y,1,1)
readAT(0,y,1,1)
readAT(0,y,1,1)
readAT(1240,630,420,100)

Image("me.png")
# Out:
# (i) FMV as of 12/31/69
# ---------------------------------------------------------------------------------------
# (j) Adjusted basis
# as of 12/31/69
# ---------------------------------------------------------------------------------------
# (k) Excess of col (1)
# overcol (j), ifany
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# (I) Gains (Col (h) gain minus
# col (k), but not less than -0-) or
# Losses (from col (h))
# ---------------------------------------------------------------------------------------

# %%
y = 730
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,385,height)
readAT(1240,y,420,height)
# Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 65,342,686
# ---------------------------------------------------------------------------------------

# %%
y = 770
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,385,height)
readAT(1240,y,420,height)
# Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 810
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,385,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 850
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,385,height)
readAT(1240,y,420,height)

Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 890
height = 40

readAT(10,y,450,height)
readAT(460,y,390,height)
readAT(850,y,385,height)
readAT(1240,y,420,height)

#Image("me.png")
# Out:
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 930
height = 80

readAT(10,y,1225,height)
readAT(1235,y,70,height)
readAT(1305,y,370,height)
# Image("me.png")
# Out:
# If gain, also enter in Part I, line 7
# Capital gain net income or (net capital loss)
#
# If (loss), enter -O- in Part I, line 7
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 98,997,289
# ---------------------------------------------------------------------------------------

# %%
y = 1015
height = 115

readAT(10,y,1225,height)
readAT(1235,y,70,height)
readAT(1305,y,370,height)
# readAT(1240,y,420,height)

#Image("me.png")
# Out:
# 3 Net short-term capital gain or (loss) as defined in sections 1222(5) and (6)
#
# If gain, also enter in Part I, line 8, column (c) (see Instructions) If (loss), enter -0-
# In Part I, line 8
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1135
height = 40

readAT(10,y,1500,height)
# readAT(1235,y,70,height)
# readAT(1305,y,370,height)
# readAT(1240,y,420,height)

#Image("me.png")
# Out:
# | Part Vv | Qualification Under Section 4940(e) for Reduced Tax on Net Investment Income
# ---------------------------------------------------------------------------------------

# %%
y = 1175
height = 100

readAT(10,y,1400,height)
# readAT(1455,y,35,height,type="checkbox",caption="Yes")
# readAT(1550,y,145,height,type="checkbox",caption="No")
# Image("me.png")
# Out:
# (For optional use by domestic private foundations subject to the section 4940(a) tax on net investment income )
#
# If section 4940(d)(2) applies, leave this part blank
# ---------------------------------------------------------------------------------------

# %%
y = 1285
height = 70

readAT(10,y,1400,height)
readAT(1455,y,35,35,type="checkbox",caption="Yes")
readAT(1560,y,35,35,type="checkbox",caption="No")
# Image("me.png")
# Out:
# Was the foundation liable for the section 4942 tax on the distributable amount of any year in the base period?
# If “Yes,” the foundation does not qualify under section 4940(e) Do not complete this part
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1350
height = 40

readAT(10,y,1450,height)
#readAT(1410,y,300,height)
# readAT(1305,y,370,height)
# readAT(1240,y,420,height)

Image("me.png")
# Out:
# 1 Enter the appropriate amount in each column for each year, see page 18 of the instructions before making any entries
# ---------------------------------------------------------------------------------------

# %%
y = 1400
height = 80

readAT(10,y,365,height, type="static")
readAT(375,y,410,height, type="static")
readAT(785,y,415,height, type="static")
readAT(1200,y,420,height, type="static")
# Image("me.png")
# Out:
# (a)
# Base penod years Calendar
# year (or tax year beginning in)
# ---------------------------------------------------------------------------------------
# (b)
# Adjusted qualifying distributions
# ---------------------------------------------------------------------------------------
# (c)
#
# Net value of noncharitable-use assets
# ---------------------------------------------------------------------------------------
# (d)
# Distribution ratio
# (col (b) divided by col (c))
# ---------------------------------------------------------------------------------------

# %%
y = 1480
height = 38

readAT(10,y,365,height)
readAT(375,y,410,height)
readAT(790,y,415,height)
readAT(1200,y,450,height)

# Image("me.png")
# Out:
# 2011
# ---------------------------------------------------------------------------------------
# 165,220,026
# ---------------------------------------------------------------------------------------
# 3,252,042,331
# ---------------------------------------------------------------------------------------
# 0050805
# ---------------------------------------------------------------------------------------

# %%
y = 1515
height = 38

readAT(10,y,365,height)
readAT(375,y,410,height)
readAT(785,y,415,height)
readAT(1200,y,450,height)
# Image("me.png")
# Out:
# 2010
# ---------------------------------------------------------------------------------------
# 175,982,054
# ---------------------------------------------------------------------------------------
# 3,198,276,575
# ---------------------------------------------------------------------------------------
# 0055024
# ---------------------------------------------------------------------------------------

# %%
y = 1550
height = 38

readAT(10,y,365,height)
readAT(375,y,410,height)
readAT(785,y,415,height)
readAT(1200,y,450,height)
# Image("me.png")
# Out:
# 2009
# ---------------------------------------------------------------------------------------
# 23,273,065
# ---------------------------------------------------------------------------------------
# 3,108,576 ,373
# ---------------------------------------------------------------------------------------
# 0 007487
# ---------------------------------------------------------------------------------------

# %%
y = 1585
height = 38

readAT(10,y,365,height)
readAT(375,y,410,height)
readAT(790,y,415,height)
readAT(1200,y,450,height)

# Image("me.png")
# Out:
# 2008
# ---------------------------------------------------------------------------------------
# 161,045,708
# ---------------------------------------------------------------------------------------
# 2,913,819 ,266
# ---------------------------------------------------------------------------------------
# 005527
# ---------------------------------------------------------------------------------------

# %%
y = 1615
height = 38

readAT(10,y,365,height)
readAT(375,y,410,height)
readAT(790,y,415,height)
readAT(1200,y,450,height)
# Image("me.png")
# Out:
# 2007
# ---------------------------------------------------------------------------------------
# 188,418,458
# ---------------------------------------------------------------------------------------
# 3,473,082,756
# ---------------------------------------------------------------------------------------
# 0054251
# ---------------------------------------------------------------------------------------

# %%
y = 1700
height = 38

readAT(10,y,1180,height)
readAT(1280,y,400,height)
# Image("me.png")
# Out:
# 2 Total of line 1, column(d). .
# ---------------------------------------------------------------------------------------
# 0 222837
# ---------------------------------------------------------------------------------------

# %%
y = 1745
height = 60

readAT(10,y,1180,height)
readAT(1280,y,400,height)
# Image("me.png")
# Out:
# 3 Average distribution ratio for the 5-year base period—divide the total on line 2 by 5, or by
# the number of years the foundation has been In existence ifless than 5 years . . .
# ---------------------------------------------------------------------------------------
# 0 044567
# ---------------------------------------------------------------------------------------

# %%
y = 1810
height = 60

readAT(10,y,1180,height)
readAT(1280,y,400,height)
# Image("me.png")
# Out:
# 4
#
# Enter the net value of noncharitable-use assets for 2012 from Part X, line 5.
# ---------------------------------------------------------------------------------------
# 3,244,109,389
# ---------------------------------------------------------------------------------------

# %%
y = 1870
height = 90

readAT(10,y,1180,height)
readAT(1280,y,400,height)
# Image("me.png")
# Out:
# 5 Multiply line 4 by line 3.
# ---------------------------------------------------------------------------------------
# 144,580,223
# ---------------------------------------------------------------------------------------

# %%
y = 1967
height = 60

readAT(10,y,1180,height)
readAT(1280,y,400,height)
# Image("me.png")
# Out:
# 6 Enter 1% of net investment income (1% of Part I, line 27b).
# ---------------------------------------------------------------------------------------
# 1,100,065
# ---------------------------------------------------------------------------------------

# %%
y = 2040
height = 60

readAT(10,y,1180,height)
readAT(1280,y,400,height)
# Image("me.png")
# Out:
# 7 Addlines5 and6. .
# ---------------------------------------------------------------------------------------
# 145,680,288
# ---------------------------------------------------------------------------------------

# %%
y = 2110
height = 60

readAT(10,y,1180,height)
readAT(1280,y,400,height)
readAT(10,y+70,1580,height, type="static")
Image("me.png")
# Out:
# 8 Enter qualifying distributions from Part XII, line 4.
# ---------------------------------------------------------------------------------------
# 182,817,448
# ---------------------------------------------------------------------------------------
# If line 8 is equal to or greater than line 7, check the box in Part VI, line 1b, and complete that part using a1% tax rate See
# the Part VI instructions
# ---------------------------------------------------------------------------------------

# %%
import json

with open('page_3.json', 'w') as fp:
    json.dump(arrFrames, fp)

# %%
import xlsxwriter

workbook = xlsxwriter.Workbook('page_3.xlsx')
ws = workbook.add_worksheet('Sheet1')
formatFont = workbook.add_format({'bold': False})


arrColumns = ["A","B","C","D","E","F"]

prevY = 0
prevX = 0

row = 0
column = 0

for dictItem in arrFrames:
    tmpY = dictItem["frame"]["y"]
    tmpX = dictItem["frame"]["x"]
    
    if tmpX != prevX and tmpY != prevY:
        row = row + 1
        column = 0
        prevX = tmpX
        prevY = tmpY
    elif tmpX != prevX and tmpY == prevY:
        column = column + 1
        prevX = tmpX
    elif tmpX == prevX and tmpY != prevY:
        row = row + 1
        prevY = tmpY

    ws.write(arrColumns[column] + '%d' % row, dictItem["value"], formatFont)
    
#ws.set_column(2, 2, 40)

workbook.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-028433035dbd> in <module>()
#      30         prevY = tmpY
#      31
# ---> 32     ws.write(arrColumns[column] + '%d' % row, dictItem["value"], formatFont)
#      33
#      34 #ws.set_column(2, 2, 40)
#
# KeyError: 'value'
