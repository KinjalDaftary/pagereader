# %%
import cv2
import sys
import pytesseract
import Database
from IPython.display import Image

# %%
arrFrames = []

# %%
def getStringInRect(x,y,width,height):
  imPath = "images/page_4.png"  
  # Uncomment the line below to provide path to tesseract manually
  # pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
 
  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' for using LSTM OCR Engine
  config = ('-l eng --oem 1 --psm 3')
 
  # Read image from disk
  im = cv2.imread(imPath, cv2.IMREAD_COLOR)

  crop_img = im[y:y+height, x:x+width]
  text = pytesseract.image_to_string(crop_img, config=config)
  return text

# %%
Image("images/page_4.png")

# %%
def plotSquare(x,y,width,height):
  imPath = "images/page_4.png"  
  # Uncomment the line below to provide path to tesseract manually
  # pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
 
  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' for using LSTM OCR Engine
  config = ('-l eng --oem 1 --psm 3')
 
  # Read image from disk
  im = cv2.imread(imPath, cv2.IMREAD_COLOR)
  cv2.rectangle(im, (x, y), (x+width, y+height), (255,0,0), 2)
  cv2.imwrite("me.png",im)

# %%
def findStringInRange(strFind,x,y,maxWidth,maxHeight):
  width = 10
  height = 10

  while height < maxHeight:
    width = 10
    while width < maxWidth:
      strTmpText = getStringInRect(x,y,width,height)
      if strTmpText == strFind:
        print(x)
        print(y)
        return x,y,width,height
      else:
        width = width + 5
    height = height + 5

# %%
if __name__ == '__main__':
 
  if len(sys.argv) < 1:
    print('Usage: python ocr_simple.py image.jpg')
    sys.exit(1)

strTmpText = "disqualified persons "
#plotSquare(10,430,790,25)
#text =  getStringInRect(10,430,790,25)
#findStringInRange("2 Savings and temporary cash investments",60,50,1000,1000)
# print(text)
# print("---------------------------------------------------------------------------------------")

# %%
def readAT(x,y,width,height,type="dynamic",caption=""):
    text =  getStringInRect(x,y,width,height)
#     plotSquare(x,y,width,height)
    
    dictTmpFrame = {}
    dictTmpFrame["frame"] = {"x":x,"y":y,"width":width,"height":height}
    dictTmpFrame["type"] = type
    dictTmpFrame["caption"] = caption
    if type == "static":
        dictTmpFrame["value"] = text
    elif type == "dynamic":
        dictTmpFrame["value"] = text
    
    arrFrames.append(dictTmpFrame.copy())
    print(text)
    print("---------------------------------------------------------------------------------------")

# %%
y = 0
height = 40

readAT(10,y,1675,height)
#readAT(10,y,1675,height)
# readAT(1025,y,240,height)
# readAT(1260,y,200,height)
# readAT(1460,y,230,height)
#Image("me.png")
# Out:
# Form 990-PF (2012) Pagced
# ---------------------------------------------------------------------------------------

# %%
y = 80
height = 35

readAT(10,y,820,height)
readAT(830,y,50,height,type="checkbox")
readAT(1360,y,300,140)
readAT(10,180,1100,height, type="static")
readAT(185,220,35,height,type="checkbox")

# Not used
# readAT(1260,y,200,height)
# readAT(1460,y,230,height)
Image("me.png")
# Out:
# 1a Exempt operating foundations described in section 4940(d)(2), check here
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 1,100,065
# ---------------------------------------------------------------------------------------
# b Domestic foundations that meet the section 4940(e) requirements in Part V, check
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
# y = 200
# height = 100

# readAT(10,y,1270,height)
# readAT(1280,y,80,height)
# readAT(1360,y,300,height)
# readAT(1260,y,200,height)
# readAT(1460,y,230,height)
# Image("me.png")

# %%
y = 290
height = 35

readAT(10,y,1270,height)
readAT(1360,y,300,height)
Image("me.png")
# Out:
# 2 Tax under section 511 (domestic section 4947(a)(1) trusts and taxable foundations only Others enter -0-)
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 330
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
# readAT(1260,y,200,height)
# readAT(1460,y,230,height)
#Image("me.png")
# Out:
# 3 Add lines 1 and 2.
# ---------------------------------------------------------------------------------------
# 1,100,065
# ---------------------------------------------------------------------------------------

# %%
y = 370
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
# Image("me.png")
# Out:
# 4 Subtitle A (income) tax (domestic section 4947(a)(1) trusts and taxable foundations only Others enter -0-)
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 410
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
#Image("me.png")
# Out:
# 5 Tax based on investment income. Subtract line 4 from line 3 If zero orless,enter-O-. .
# ---------------------------------------------------------------------------------------
# 1,100,065
# ---------------------------------------------------------------------------------------

# %%
y = 450
height = 40

readAT(10,y,1270,height)
# readAT(1280,y,80,height)
# readAT(1360,y,300,height)
# Image("me.png")
# Out:
# 6 Credits/Payments
# ---------------------------------------------------------------------------------------

# %%
y = 490
height = 40

readAT(10,y,940,height)
readAT(1030,y,250,height)
# Image("me.png")
# Out:
# a 2012 estimated tax payments and 2011 overpayment credited to 2012
# ---------------------------------------------------------------------------------------
# 3,500,000
# ---------------------------------------------------------------------------------------

# %%
y = 530
height = 40

readAT(10,y,940,height)
readAT(1030,y,250,height)
# Image("me.png")
# Out:
# b Exempt foreign organizations—tax withheld at source .
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 570
height = 40

readAT(10,y,940,height)
readAT(1030,y,250,height)
# Image("me.png")
# Out:
# c  7ax paid with application for extension of time to file (Form 8868)
# ---------------------------------------------------------------------------------------
# 287,849
# ---------------------------------------------------------------------------------------

# %%
y = 610
height = 35

readAT(10,y,940,height)
readAT(1030,y,250,height)
# Image("me.png")
# Out:
# d= Backup withholding erroneously withheld .
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 650
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
# Image("me.png")
# Out:
# 7 Total credits and payments Add lines 6a through 6d.
# ---------------------------------------------------------------------------------------
# 3,787,849
# ---------------------------------------------------------------------------------------

# %%
y = 690
height = 40

readAT(10,y,1270,height)
readAT(855,y,35,height)
readAT(1360,y,300,height)
# Image("me.png")
# Out:
# 8 Enter any penalty for underpayment of estimated tax Check here Jv if Form 2220 ts attached )
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 730
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
#Image("me.png")
# Out:
# 9 Tax due. If the total of lines 5 and 8 Is more than line 7, enter amount owed .
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 765
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
# Image("me.png")
# Out:
# 10 Overpayment. If line 7 Is more than the total of lines 5 and 8, enter the amount overpaid.
# ---------------------------------------------------------------------------------------
# 2,687,784
# ---------------------------------------------------------------------------------------

# %%
y = 805
height = 40

readAT(10,y,1270,height)
readAT(1360,y,300,height)
# Image("me.png")
# Out:
# 11 Enter the amount of line 10 to be Credited to 2013 estimated tax 1,000,000 Refunded
# ---------------------------------------------------------------------------------------
# 1,687,784
# ---------------------------------------------------------------------------------------

# %%
y = 845
height = 37

readAT(10,y,1650,height)
# Image("me.png")
# Out:
# | Part VII-A | Statements Regarding Activities
# ---------------------------------------------------------------------------------------

# %%
y = 913
height = 40

readAT(10,y-38,1430,height)
readAT(10,y,1430,height)
readAT(1520,y,75,height)
readAT(1595,y,75,height)
Image("me.png")
# Out:
# la During the tax year, did the foundation attempt to influence any national, state, or local legislation or did
# ---------------------------------------------------------------------------------------
# it participate or intervene in any political campaign? )
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 958
height = 75

readAT(10,y,1430,height)
readAT(1520,y,75,height)
readAT(1595,y,75,height)
# Image("me.png")
# Out:
# b= Didit spend more than $100 during the year (either directly or indirectly) for political purposes (see page 19 of
# the instructions for definition)? i
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 1032
height = 120

readAT(10,y,1430,height)
readAT(1520,y,75,height)
readAT(1595,y,75,height)
# Image("me.png")
# Out:
# If the answer is “Yes” to la or 1b, attach a detailed description of the activities and copies of any materials
# published or distributed by the foundation in connection with the activities.
# ¢ Didthe foundation file Form1120-POL forthis year?. . . . 2 2 2 8 we we ew we ew ee
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 1150
height = 80

readAT(10,y,1430,height)
# Image("me.png")
# Out:
# d= Enter the amount (if any) of tax on political expenditures (section 4955) imposed during the year
# (1) On the foundation  ¢$ O (2) On foundation managers * $
# ---------------------------------------------------------------------------------------

# %%
y = 1230
height = 80

readAT(10,y,1430,height)
# Image("me.png")
# Out:
# e Enter the reimbursement (if any) paid by the foundation during the year for political expenditure tax imposed
# on foundation managers  $ Q
# ---------------------------------------------------------------------------------------

# %%
y = 1310
height = 30

readAT(10,y,1430,height)
readAT(1520,y,75,height)
readAT(1595,y,75,height)
# Image("me.png")
# Out:
# 2
#
# Has the foundation engaged In any activities that have not previously been reported to the IRS?
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 1345
height = 110

readAT(10,y,1430,height)
readAT(1520,y,70,height)
readAT(1595,y,75,height)
# Image("me.png")
# Out:
# If “Yes,” attach a detailed description of the activities.
# 3 Has the foundation made any changes, not previously reported to the IRS, in its governing Instrument, articles
#
# of incorporation, or bylaws, or other similar instruments? Jf “Yes,” attach a conformed copy of the chances) soe
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 1460
height = 40

readAT(10,y,1430,height)
readAT(1530,y,60,40)
readAT(1595,y,60,40)
# Image("me.png")
# Out:
# 4a Did the foundation have unrelated business gross income of $1,000 or more during the year?. .
# ---------------------------------------------------------------------------------------
# Yes
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1500
height = 40

readAT(10,y,1430,height)
readAT(1530,y,60,height)
readAT(1595,y,60,height)
# Image("me.png")
# Out:
# b_ If “Yes,” has it filed a tax return on Form 990-T for this year?.
# ---------------------------------------------------------------------------------------
# Yes
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1540
height = 40

readAT(10,y,1430,height)
readAT(1527,y,70,height)
readAT(1595,y,75,height)
#Image("me.png")
# Out:
# 5 Was there a liquidation, termination, dissolution, or substantial contraction during the year? .
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 1580
height = 190

readAT(10,y,1430,height)
readAT(1530,y,60,height)
readAT(1595,y,60,height)
# Image("me.png")
# Out:
# If “Yes,” attach the statement required by General Instruction 7.
#
# 6 Are the requirements of section 508(e) (relating to sections 4941 through 4945) satisfied either
# e@ By language in the governing instrument, or
#
# e@ By state legislation that effectively amends the governing Instrument so that no mandatory directions
#
# that conflict with the state law remain in the governing Instrument?
# ---------------------------------------------------------------------------------------
# Yes
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1770
height = 40

readAT(10,y,1430,height)
readAT(1450,y,77,height)
readAT(1527,y,70,height)
readAT(1595,y,75,height)
#Image("me.png")
# Out:
# 7 Did the foundation have at least $5,000 in assets at any time during the year? If "Yes,” complete Part II, col (c), and Part XV
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# ‘Yes |
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1820
height = 140

readAT(10,y,1430,height)
readAT(1527,y,70,height)
readAT(1595,y,75,height)
# Image("me.png")
# Out:
# 8a_ Enter the states to which the foundation reports or with which It is registered (see Instructions)
# ee
# b_ Ifthe answer is “Yes” to line 7, has the foundation furnished a copy of Form 990-PF to the Attorney
# General (or designate) of each state as required by General Instruction G? If "No," attach explanation .
# ---------------------------------------------------------------------------------------
# Yes
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y = 1960
height = 120

readAT(10,y,1430,height)
readAT(1530,y,60,height)
readAT(1595,y,75,height)
# Image("me.png")
# Out:
# 9 Is the foundation claiming status as a private operating foundation within the meaning of section 4942 (j)(3)
# or 4942(j)(5) for calendar year 2012 or the taxable year beginning in 2012 (see instructions for Part XIV )?
# If “Yes,” complete Part XIV ee
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
y = 2080
height = 35

readAT(10,y,1430,height)
readAT(1527,y,70,height)
readAT(1595,y,70,height)
# Image("me.png")
# Out:
# 10 Did any persons become substantial contributors during the tax year? If “Yes,” attach a schedule listing their names and addresses
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# No
# ---------------------------------------------------------------------------------------

# %%
import json

with open('page_4.json', 'w') as fp:
    json.dump(arrFrames, fp)

# %%
import xlsxwriter

workbook = xlsxwriter.Workbook('page_4.xlsx')
ws = workbook.add_worksheet('Sheet1')
formatFont = workbook.add_format({'bold': False})


arrColumns = ["A","B","C","D","E","F"]

prevY = 0
prevX = 0

row = 0
column = 0

for dictItem in arrFrames:
    tmpY = dictItem["frame"]["y"]
    tmpX = dictItem["frame"]["x"]
    
    if tmpX != prevX and tmpY != prevY:
        row = row + 1
        column = 0
        prevX = tmpX
        prevY = tmpY
    elif tmpX != prevX and tmpY == prevY:
        column = column + 1
        prevX = tmpX
    elif tmpX == prevX and tmpY != prevY:
        row = row + 1
        prevY = tmpY

    ws.write(arrColumns[column] + '%d' % row, dictItem["value"], formatFont)
    
#ws.set_column(2, 2, 40)

workbook.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-417da0fc7971> in <module>()
#      30         prevY = tmpY
#      31
# ---> 32     ws.write(arrColumns[column] + '%d' % row, dictItem["value"], formatFont)
#      33
#      34 #ws.set_column(2, 2, 40)
#
# KeyError: 'value'
