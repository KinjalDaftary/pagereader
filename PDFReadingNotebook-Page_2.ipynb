# %%
import cv2
import sys
import pytesseract
import Database
from IPython.display import Image

# %%
arrFrames = []

# %%
def getStringInRect(x,y,width,height):
  imPath = "images/page_2.png"  
  # Uncomment the line below to provide path to tesseract manually
  # pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
 
  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' for using LSTM OCR Engine
  config = ('-l eng --oem 1 --psm 3')
 
  # Read image from disk
  im = cv2.imread(imPath, cv2.IMREAD_COLOR)

  crop_img = im[y:y+height, x:x+width]
  text = pytesseract.image_to_string(crop_img, config=config)
  return text

# %%
Image("images/page_2.png")

# %%
def plotSquare(x,y,width,height):
  imPath = "images/page_2.png"  
#   imPath = "harshit_highlight.png"  
  # Uncomment the line below to provide path to tesseract manually
  # pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'
 
  # Define config parameters.
  # '-l eng'  for using the English language
  # '--oem 1' for using LSTM OCR Engine
  config = ('-l eng --oem 1 --psm 3')
 
  # Read image from disk
  im = cv2.imread(imPath, cv2.IMREAD_COLOR)
  cv2.rectangle(im, (x, y), (x+width, y+height), (255,0,0), 2)
  cv2.imwrite("harshit_highlight.png",im)

# %%
def findStringInRange(strFind,x,y,maxWidth,maxHeight):
  width = 10
  height = 10

  while height < maxHeight:
    width = 10
    while width < maxWidth:
      strTmpText = getStringInRect(x,y,width,height)
      if strTmpText == strFind:
        print(x)
        print(y)
        return x,y,width,height
      else:
        width = width + 5
    height = height + 5

# %%
if __name__ == '__main__':
 
  if len(sys.argv) < 1:
    print('Usage: python ocr_simple.py image.jpg')
    sys.exit(1)

strTmpText = "disqualified persons "
#plotSquare(10,430,790,25)
#text =  getStringInRect(10,430,790,25)
#findStringInRange("2 Savings and temporary cash investments",60,50,1000,1000)
# print(text)
# print("---------------------------------------------------------------------------------------")

# %%
def readAT(x,y,width,height,type="dynamic",caption=""):
    text =  getStringInRect(x,y,width,height)
    plotSquare(x,y,width,height)
    
    dictTmpFrame = {}
    dictTmpFrame["frame"] = {"x":x,"y":y,"width":width,"height":height}
    dictTmpFrame["type"] = type
    dictTmpFrame["caption"] = caption
    if type == "static":
        dictTmpFrame["value"] = text
    elif type == "dynamic":
        dictTmpFrame["value"] = text
    
    arrFrames.append(dictTmpFrame.copy())
    print(text)
    print("---------------------------------------------------------------------------------------")

# %%
theY = 50
height = 26
lines = 2

readAT(140,theY,200, lines*height + lines, type="static")
readAT(340,theY,600, lines*height + lines, type="static")
readAT(970,theY,230,height, type="static")
readAT(1201,theY,460,height, type="static")
readAT(0,theY + height,5,5, type="static")
readAT(970,theY + height,230,height, type="static")
readAT(1201,theY + height,230,height, type="static")
readAT(1433,theY + height,229,height, type="static")
# readAT(1432,y2,230,lines*height + lines)
Image("harshit_highlight.png")
# Out:
# Balance Sheets
# ---------------------------------------------------------------------------------------
# Attached schedules and amounts in the description column
# should be for end-of-year amounts only (See instructions )
# ---------------------------------------------------------------------------------------
# Beginning of year
# ---------------------------------------------------------------------------------------
# End of year
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# (a) Book Value
# ---------------------------------------------------------------------------------------
# (b) Book Value
# ---------------------------------------------------------------------------------------
# (c) Fair Market Value
# ---------------------------------------------------------------------------------------

# %%
y = 110
height = 35

readAT(70,y,895,height,type="static")
readAT(970,y,230,height)
readAT(1201,y,230,height)
readAT(1432,y,230,height)
#Image("harshit_highlight.png")
# Out:
# 1 Cash—non-interest-bearing.
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y1 = y + height + 2
readAT(68,y1,895,height,type="static")
readAT(970,y1,230,height)
readAT(1201,y1,230,height)
readAT(1432,y1,230,height)
#Image("harshit_highlight.png")
# Out:
# 2 Savings and temporary cash investments
# ---------------------------------------------------------------------------------------
# 165,341,887
# ---------------------------------------------------------------------------------------
# 71,251,183
# ---------------------------------------------------------------------------------------
# 71,251,183
# ---------------------------------------------------------------------------------------

# %%
y2 = y1 + height + 5
lines = 2
readAT(68,y2,895, lines*height + lines)
readAT(970,y2,230,lines*height + lines)
readAT(1201,y2,230,lines*height + lines)
readAT(1432,y2,230,lines*height + lines)
#Image("harshit_highlight.png")
# Out:
# 3 Accounts receivable
#
# Less allowance for doubtful accounts
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y3 = y2 + (2*height)  + (2*5)
lines = 2
readAT(68,y3,895, lines*height + lines)
readAT(970,y3,230,lines*height + lines)
readAT(1201,y3,230,lines*height + lines)
readAT(1432,y3,230,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 4 Pledges receivable
# Less allowance for doubtful accounts *
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
y4 = y3 + (2*height)  + (2*5)
lines = 1
readAT(68,y4,895, lines*height + lines,type="static")
readAT(970,y4,230,lines*height + lines)
readAT(1201,y4,230,lines*height + lines)
readAT(1432,y4,230,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 5
#
# Grants receivable
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y5 = y4 + (previousLines*height)  + (previousLines*5)
lines = 3
readAT(68,y5,895, lines*height + lines,type="static")
readAT(970,y5,230,lines*height + lines)
readAT(1201,y5,230,lines*height + lines)
readAT(1432,y5,230,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 6 Receivables due from officers, directors, trustees, and other
# disqualified persons (attach schedule) (see page 15 of the
#
# Instructions). 2 8 ewe
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 3
y6 = y5 + (previousLines*height)
lines = 3
readAT(68,y6,895, lines*height + lines)
readAT(970,y6,230,lines*height + lines)
readAT(1201,y6,230,lines*height + lines)
readAT(1432,y6,230,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 7 Other notes and loans receivable (attach schedule)
#
# Less allowance for doubtful accounts
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 3
y7 = y6 + (previousLines*height)
lines = 1
readAT(68,y7,895, lines*height + lines,type="static")
readAT(970,y7,230,lines*height + lines)
readAT(1201,y7,230,lines*height + lines)
readAT(1432,y7,230,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 8 Inventories forsale oruse . .
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y8 = y7 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(68,y8,895, lines*height + lines,type="static")
readAT(970,y8,230,lines*height + lines)
readAT(1201,y8,230,lines*height + lines)
readAT(1432,y8,230,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 9 Prepaid expenses and deferred charges .
# ---------------------------------------------------------------------------------------
# 2,686,275
# ---------------------------------------------------------------------------------------
# 1,094,348
# ---------------------------------------------------------------------------------------
# 1,094,348
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y9 = y8 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y9,895, lines*height + lines,type="static")
readAT(970,y9,230,lines*height + lines)
readAT(1250,y9,180,lines*height + lines)
readAT(1440,y9,220,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 10a Investments—U S and state government obligations (attach schedule)
# ---------------------------------------------------------------------------------------
# 126,085,959
# ---------------------------------------------------------------------------------------
# 3,519,955
# ---------------------------------------------------------------------------------------
# 3,519,955
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y10 = y9 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y10,895, lines*height + lines,type="static")
readAT(970,y10,230,lines*height + lines)
readAT(1250,y10,180,lines*height + lines)
readAT(1440,y10,220,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# b Investments—corporate stock (attach schedule) .
# ---------------------------------------------------------------------------------------
# 1,223,969,757
# ---------------------------------------------------------------------------------------
# 1,210,805,196
# ---------------------------------------------------------------------------------------
# 1,210,805, 196
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y11 = y10 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y11,895, lines*height + lines,type="static")
readAT(970,y11,230,lines*height + lines)
readAT(1250,y11,180,lines*height + lines)
readAT(1440,y11,220,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# c Investments—corporate bonds (attach schedule).
# ---------------------------------------------------------------------------------------
# 364,583,699
# ---------------------------------------------------------------------------------------
# 206,826,887
# ---------------------------------------------------------------------------------------
# 206,826,887
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y12 = y11 + (previousLines*height) + (previousLines*5)
lines = 2
readAT(60,y12,895, lines*height + lines)
readAT(970,y12,230,lines*height + lines)
readAT(1250,y12,180,lines*height + lines)
readAT(1440,y12,220,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 11. Investments—land, buildings, and equipment basis
#
# Less accumulated depreciation (attach schedule)
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y13 = y12 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y13,895, lines*height + lines,type="static")
readAT(970,y13,230,lines*height + lines)
readAT(1250,y13,180,lines*height + lines)
readAT(1440,y13,220,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 12 Investments—mortgage loans
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y14 = y13 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y14,895, lines*height + lines,type="static")
readAT(970,y14,230,lines*height + lines)
readAT(1250,y14,180,lines*height + lines)
readAT(1440,y14,220,lines*height + lines)
readAT(60,y14 + (lines*height + lines) ,895, lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 13. Investments—other (attach schedule) .
# ---------------------------------------------------------------------------------------
# 1,675,841,414
# ---------------------------------------------------------------------------------------
# 1,956,765,505
# ---------------------------------------------------------------------------------------
# 1,956,765,505
# ---------------------------------------------------------------------------------------
# 14. ~=~Land, buildings, and equipment basis 104,877,218
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y15 = y14 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y15,895, lines*height + lines)
readAT(1000,y15,200,lines*height + lines)
readAT(1250,y15,180,lines*height + lines)
readAT(1480,y15,180,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# Less accumulated depreciation (attach schedule) 28,285,756
# ---------------------------------------------------------------------------------------
# 79,285,432
# ---------------------------------------------------------------------------------------
# 76,591,462
# ---------------------------------------------------------------------------------------
# 76,591,462
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y16 = y15 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y16,895, lines*height + lines)
readAT(1000,y16,200,lines*height + lines)
readAT(1250,y16,180,lines*height + lines)
readAT(1480,y16,180,lines*height + lines)
#readAT(60,y16 + (lines*height + lines),895, lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 15 Other assets (describe ik
# ---------------------------------------------------------------------------------------
# 22,753,872
# ---------------------------------------------------------------------------------------
# 35,293,744
# ---------------------------------------------------------------------------------------
# 35,293,744
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y17 = y16 + (previousLines*height) + (previousLines*5)
lines = 2
readAT(60,y17,895, lines*height + lines, type="static")
readAT(1000,y17,200,lines*height + lines)
readAT(1250,y17,180,lines*height + lines)
readAT(1480,y17,185,lines*height + lines)
Image("harshit_highlight.png")
# Out:
# 16 Total assets (to be completed by all filers—see the
#
# Instructions Also, see page 1, Item1)
# ---------------------------------------------------------------------------------------
# 3,660,548,295
# ---------------------------------------------------------------------------------------
# 3,562,148,280
# ---------------------------------------------------------------------------------------
# 3,562,148,280
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y18 = y17 + (previousLines*height) + (previousLines*5)
lines = 1
readAT(60,y18,895, lines*height + lines,type="static")
readAT(1000,y18,200,lines*height + lines)
readAT(1250,y18,180,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 17 Accounts payable and accrued expenses .
# ---------------------------------------------------------------------------------------
# 6,058,502
# ---------------------------------------------------------------------------------------
# 8,123,823
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y19 = y18 + (previousLines*height) + (previousLines*5)
tmpY = y19
lines = 1
readAT(60,tmpY,895, lines*height + lines,type="static")
readAT(1000,tmpY,200,lines*height + lines)
readAT(1250,tmpY,180,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 18 Grants payable .
# ---------------------------------------------------------------------------------------
# 34,058,536
# ---------------------------------------------------------------------------------------
# 61,547,013
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y20 = y19 + (previousLines*height) + (previousLines*5)
tmpY = y20
lines = 1
readAT(60,tmpY,895, lines*height + lines,type="static")
readAT(1000,tmpY,200,lines*height + lines)
readAT(1250,tmpY,180,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 19 Deferred revenue
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y21 = y20 + (previousLines*height) + (previousLines*5)
tmpY = y21
lines = 1
readAT(60,tmpY,895, lines*height + lines,type="static")
readAT(1000,tmpY,200,lines*height + lines)
readAT(1250,tmpY,180,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 20 Loans from officers, directors, trustees, and other disqualified persons
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y22 = y21 + (previousLines*height) + (previousLines*5)
tmpY = y22
lines = 1
readAT(60,tmpY,895, lines*height + lines,type="static")
readAT(1000,tmpY,200,lines*height + lines)
readAT(1250,tmpY,180,lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# 21 Mortgages and other notes payable (attach schedule)
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y23 = y22 + (previousLines*height) + (previousLines*5)
tmpY = y23
lines = 2
readAT(60,tmpY,895, lines*height - lines)
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# 22 Other liabilities (describe
# ---------------------------------------------------------------------------------------
# 330,892,230
# ---------------------------------------------------------------------------------------
# 99,961,773
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y24 = y23 + (previousLines*height) 
tmpY = y24
lines = 2
readAT(60,tmpY,895, lines*height - lines,type="static")
# Image("harshit_highlight.png")
# Out:
# 23 =‘ Total liabilities (add lines 17 through 22)
# ns that follow SFAS 117, check here F [7
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y25 = y24 + (previousLines*height) + (previousLines*5)
tmpY = y25
lines = 2
readAT(60,tmpY,895, lines*height - lines)
readAT(716,tmpY,35, 35,type="checkbox")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# Foundations that follow SFAS 117, check here jy
# and complete lines 24 through 26 and lines 30 and 31.
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y26 = y25 + (previousLines*height) + (previousLines*5)
tmpY = y26
lines = 1
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# and complete lines 24 through 26 and lines 30 and 31.
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y27 = y26 + (previousLines*height) + (previousLines*5)
tmpY = y27
lines = 1
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# 24 Unrestricted.
# ---------------------------------------------------------------------------------------
# 3,289,539,027
# ---------------------------------------------------------------------------------------
# 3,392,515,671
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y28 = y27 + (previousLines*height) + (previousLines*5)
tmpY = y28
lines = 1
readAT(60,tmpY,895, lines*height - lines, type="static")
readAT(1000,tmpY,200, lines*height - lines)
readAT(1250,tmpY,180, lines*height - lines)

tmpY = y28 + (previousLines*height) + (previousLines*5)
readAT(60,tmpY,895, lines*height - lines, type="static")
readAT(1000,tmpY,200, lines*height - lines)
readAT(1250,tmpY,180, lines*height - lines)
y28 = tmpY 
# Image("harshit_highlight.png")
# Out:
# 25
#
# Temporarily restricted
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 26
#
# Permanently restricted
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y29 = y28 + (previousLines*height) + (previousLines*5)
tmpY = y29
lines = 1
readAT(120,tmpY - 40,640, lines*height - lines)
readAT(800,tmpY - 40,35, 35)
readAT(60,tmpY,895, lines*height - lines)

# Image("harshit_highlight.png")
# Out:
# Foundations that do not follow SFAS 117, check here
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# and complete lines 27 through 31.
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y30 = y29 + (previousLines*height) + (previousLines*5)
tmpY = y30
lines = 1
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# 27. Capital stock, trust principal, or current funds .
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y31 = y30 + (previousLines*height) + (previousLines*5)
tmpY = y31
lines = 1
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# 28  Paid-in or capital surplus, or land, bldg , and equipment fund
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y32 = y31 + (previousLines*height) + (previousLines*5)
tmpY = y32
lines = 1
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)

tmpY = y32 + (previousLines*height) + (previousLines*5)
lines = 2
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
y32 = tmpY

# Image("harshit_highlight.png")
# Out:
# 29 ~=Retained earnings, accumulated income, endowment, or other funds
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 30 =Total net assets or fund balances (see page 17 of the
#
# Instructions) .
# ---------------------------------------------------------------------------------------
# 3,289,539,027
# ---------------------------------------------------------------------------------------
# 3,392,515,671
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y33 = y32 + (previousLines*height) + (previousLines*5)
tmpY = y33
lines = 2
readAT(60,tmpY,895, lines*height - lines,type="static")
readAT(1000,tmpY,200,lines*height - lines)
readAT(1250,tmpY,180,lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# 31 ‘Total liabilities and net assets/fund balances (see page 17 of
#
# the instructions) .« .« «© 6 8 8 8 8 8 ee ee ee
# ---------------------------------------------------------------------------------------
# 3,660,548,295
# ---------------------------------------------------------------------------------------
# 3,562, 148,280
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y34 = y33 + (previousLines*height) + (previousLines*5)
tmpY = y34
lines = 2
readAT(20,tmpY,130, lines*height - lines)
readAT(150,tmpY,995, lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# ---------------------------------------------------------------------------------------
# Analysis of Changes in Net Assets or Fund Balances
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y35 = y34 + (previousLines*height)
tmpY = y35
lines = 2
readAT(20,tmpY,1295, lines*height - lines,type="static")
readAT(1330,tmpY,50, lines*height - lines)
readAT(1400,tmpY,260, lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# Total net assets or fund balances at beginning of year—Part II, column (a), line 30 (must agree
# with end-of-year figure reported on prior year’s return) a
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 3,289,539,027
# ---------------------------------------------------------------------------------------

# %%
previousLines = 2
y36 = y35 + (previousLines*height)
tmpY = y36
lines = 1
readAT(20,tmpY,1295, lines*height - lines,type="static")
readAT(1330,tmpY,50, lines*height - lines)
readAT(1400,tmpY,260, lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# Enter amount from PartI1. line 27a
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# -58.624.745
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y37 = y36 + (previousLines*height) + (previousLines*5)
tmpY = y37
lines = 1
readAT(20,tmpY,1295, lines*height + lines)
readAT(1330,tmpY,50, lines*height - lines)
readAT(1400,tmpY,260, lines*height - lines)
# Image("harshit_highlight.png")
# Out:
# Other increases not included tn line 2 (itemize) *
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 162,263,270
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y38 = y37 + (previousLines*height) + (previousLines*5)
tmpY = y38
lines = 1
readAT(20,tmpY,1295, lines*height - lines,type="static")
readAT(1330,tmpY,50, lines*height + lines)
readAT(1400,tmpY,260, lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# Add lines 1,2, and 3
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 3,393,177,552
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y39 = y38 + (previousLines*height) + (previousLines*5)
tmpY = y39
lines = 1
readAT(20,tmpY,1295, lines*height + lines)
readAT(1330,tmpY,50, lines*height - lines)
readAT(1400,tmpY,260, lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# Decreases not included tn line 2 (itemize) *
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 661,881
# ---------------------------------------------------------------------------------------

# %%
previousLines = 1
y40 = y39 + (previousLines*height) + (previousLines*5)
tmpY = y40
lines = 1
readAT(20,tmpY,1295, lines*height + lines,type="static")
readAT(1330,tmpY,50, lines*height - lines)
readAT(1400,tmpY,260, lines*height + lines)
# Image("harshit_highlight.png")
# Out:
# Total net assets or fund balances at end of year (line 4 minus line 5)—Part II, column (b), line 30
# ---------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------
# 3,392,515,671
# ---------------------------------------------------------------------------------------

# %%
import json

with open('page_2.json', 'w') as fp:
    json.dump(arrFrames, fp)

# %%
import xlsxwriter

workbook = xlsxwriter.Workbook('page_2.xlsx')
ws = workbook.add_worksheet('Sheet1')
formatFont = workbook.add_format({'bold': False})


arrColumns = ["A","B","C","D","E","F"]

prevY = 0
prevX = 0

row = 0
column = 0

for dictItem in arrFrames:
    tmpY = dictItem["frame"]["y"]
    tmpX = dictItem["frame"]["x"]
    
    if tmpX != prevX and tmpY != prevY:
        row = row + 1
        column = 0
        prevX = tmpX
        prevY = tmpY
    elif tmpX != prevX and tmpY == prevY:
        column = column + 1
        prevX = tmpX
    elif tmpX == prevX and tmpY != prevY:
        row = row + 1
        prevY = tmpY

    ws.write(arrColumns[column] + '%d' % row, dictItem["value"], formatFont)
    
#ws.set_column(2, 2, 40)

workbook.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-79e372b915c5> in <module>()
#      30         prevY = tmpY
#      31
# ---> 32     ws.write(arrColumns[column] + '%d' % row, dictItem["value"], formatFont)
#      33
#      34 #ws.set_column(2, 2, 40)
#
# KeyError: 'value'
